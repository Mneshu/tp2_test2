# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.set_theme()

# %%
sns.set_style("whitegrid")

# %%
data_read=pd.read_csv("C:/Users/Sfundesihle/Desktop/test/dataset - 2020-09-24.csv")

# %%
sns.set_style("whitegrid")

# %%
raws = 5


data_raw = data['Club'].head(raws)


Name = data['Wins']
data = Name.head(raws)
plt.figure(figsize=(4,5))

sns.lineplot( x=data_raw, y=data, data=data)
plt.xlabel('Clubs')
plt.ylabel('Wins')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 4
#       1 raws = 5
# ----> 4 data_raw = data['Club'].head(raws)
#       7 Name = data['Wins']
#       8 data = Name.head(raws)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
# ...

# %%
sns.lineplot(x='Clean sheets', y='Saves', data=data_read)
plt.show()
# Out:
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_context("talk")
sns.lineplot(x='Clean sheets', y='Saves', data=data_read)
plt.show()
# Out:
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.kdeplot(data=data_read['Wins'],
shade=True)
# Out:
# C:\Users\Sfundesihle\AppData\Local\Temp\ipykernel_14172\3501030951.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data_read['Wins'],
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Wins', ylabel='Density'>

# %%
sns.rugplot(data_read['Wins'])
# Out:
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Wins'>

# %%
sns.boxplot(x='Club', y='Wins', data=data_read)
# Out:
# <Axes: xlabel='Club', ylabel='Wins'>

# %%
sns.violinplot(x='Club', y='Losses', data=data_read)
# Out:
# <Axes: xlabel='Club', ylabel='Losses'>

# %%
sns.swarmplot(x='Losses', y='Wins', data=data_read)
# Out:
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 99.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sfundesihle\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 94.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.pairplot(data_read, hue='Appearances')

# %%
sns.jointplot(x='Wins', y='Appearances', data=data_read,
kind='scatter')
